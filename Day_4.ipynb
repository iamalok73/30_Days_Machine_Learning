# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
print("All lbreries import successfully")
# Out:
# All lbreries import successfully

# %%
df = pd.read_excel(r"C:\Users\Alok\Downloads\LIC.xlsx")

# %%
df
# Out:
#    Age  Buy
# 0   19    0
# 1   20    0
# 2   32    0
# 3   38    1
# 4   40    0
# 5   46    1
# 6   53    1
# 7   60    0

# %%
plt.scatter(df[["Age"]],df[["Buy"]],color = "r",marker="d")
plt.plot(df[["Age"]],df[["Buy"]])

# %%
X = np.linspace(-20,20,70)
X
# Out:
# array([-20.        , -19.42028986, -18.84057971, -18.26086957,
#        -17.68115942, -17.10144928, -16.52173913, -15.94202899,
#        -15.36231884, -14.7826087 , -14.20289855, -13.62318841,
#        -13.04347826, -12.46376812, -11.88405797, -11.30434783,
#        -10.72463768, -10.14492754,  -9.56521739,  -8.98550725,
#         -8.4057971 ,  -7.82608696,  -7.24637681,  -6.66666667,
#         -6.08695652,  -5.50724638,  -4.92753623,  -4.34782609,
#         -3.76811594,  -3.1884058 ,  -2.60869565,  -2.02898551,
#         -1.44927536,  -0.86956522,  -0.28985507,   0.28985507,
#          0.86956522,   1.44927536,   2.02898551,   2.60869565,
#          3.1884058 ,   3.76811594,   4.34782609,   4.92753623,
#          5.50724638,   6.08695652,   6.66666667,   7.24637681,
#          7.82608696,   8.4057971 ,   8.98550725,   9.56521739,
#         10.14492754,  10.72463768,  11.30434783,  11.88405797,
#         12.46376812,  13.04347826,  13.62318841,  14.20289855,
# ...

# %%
import math

# %%
1/(1+math.e**-(-76))
# Out:
# 9.854154686111299e-34

# %%
Data = 1/(1+math.e**-(X))
Data
# Out:
# array([2.06115362e-09, 3.68023268e-09, 6.57113203e-09, 1.17328929e-08,
#        2.09493244e-08, 3.74054541e-08, 6.67882148e-08, 1.19251741e-07,
#        2.12926446e-07, 3.80184538e-07, 6.78827203e-07, 1.21205945e-06,
#        2.16415532e-06, 3.86413780e-06, 6.89947752e-06, 1.23190940e-05,
#        2.19957858e-05, 3.92732548e-05, 7.01210506e-05, 1.25195699e-04,
#        2.23517545e-04, 3.99025170e-04, 7.12244498e-04, 1.27101626e-03,
#        2.26716243e-03, 4.04086932e-03, 7.19222680e-03, 1.27697262e-02,
#        2.25741730e-02, 3.96043720e-02, 6.85808754e-02, 1.16193062e-01,
#        1.90113114e-01, 2.95344779e-01, 4.28039348e-01, 5.71960652e-01,
#        7.04655221e-01, 8.09886886e-01, 8.83806938e-01, 9.31419125e-01,
#        9.60395628e-01, 9.77425827e-01, 9.87230274e-01, 9.92807773e-01,
#        9.95959131e-01, 9.97732838e-01, 9.98728984e-01, 9.99287756e-01,
#        9.99600975e-01, 9.99776482e-01, 9.99874804e-01, 9.99929879e-01,
# ...

# %%
plt.plot(Data)
plt.axhline(y= 0.5)

# %%
train_test_split(df[["Age"]],df["Buy"],random_state=42, shuffle=True,test_size=.2)
# Out:
# [   Age
#  0   19
#  7   60
#  2   32
#  4   40
#  3   38
#  6   53,
#     Age
#  1   20
#  5   46,
#  0    0
#  7    0
#  2    0
#  4    0
#  3    1
#  6    1
#  Name: Buy, dtype: int64,
#  1    0
#  5    1
#  Name: Buy, dtype: int64]

# %%
X_train,X_test,y_train,y_test = train_test_split(df[["Age"]],df["Buy"],random_state=42, shuffle=True,test_size=.2)

# %%
X_train
# Out:
#    Age
# 0   19
# 7   60
# 2   32
# 4   40
# 3   38
# 6   53

# %%
X_test
# Out:
#    Age
# 1   20
# 5   46

# %%
y_train
# Out:
# 0    0
# 7    0
# 2    0
# 4    0
# 3    1
# 6    1
# Name: Buy, dtype: int64

# %%
y_test
# Out:
# 1    0
# 5    1
# Name: Buy, dtype: int64

# %%
len(X_train)
# Out:
# 6

# %%
len(X_test)
# Out:
# 2

# %%
model = LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.5

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0], dtype=int64)

# %%
X_test
# Out:
#    Age
# 1   20
# 5   46

# %%
y_test
# Out:
# 1    0
# 5    1
# Name: Buy, dtype: int64

# %%
df
# Out:
#    Age  Buy
# 0   19    0
# 1   20    0
# 2   32    0
# 3   38    1
# 4   40    0
# 5   46    1
# 6   53    1
# 7   60    0

# %%
model.predict([[93]])
# Out:
# C:\Users\Alok\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
model.predict([[93]])
# Out:
# array([1], dtype=int64)
