# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print("All libreries import successfully")
# Out:
# All libreries import successfully

# %%
df = pd.read_csv(r"C:\Users\Alok\Downloads\canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.tail(7)
# Out:
#     year  per capita income (US$)
# 40  2010              38420.52289
# 41  2011              42334.71121
# 42  2012              42665.25597
# 43  2013              42676.46837
# 44  2014              41039.89360
# 45  2015              35175.18898
# 46  2016              34229.19363

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 884.0 bytes

# %%
df.shape
# Out:
# (47, 2)

# %%
X_train = df.loc[:36, ['year']]

# %%
X_train.head()
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
y_train = df.loc[:36,"per capita income (US$)"]

# %%
y_train.head()
# Out:
# 0    3399.299037
# 1    3768.297935
# 2    4251.175484
# 3    4804.463248
# 4    5576.514583
# Name: per capita income (US$), dtype: float64

# %%
X_test = df.loc[36:, ["year"]]

# %%
X_test
# Out:
#     year
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y_test = df.loc[36: , "per capita income (US$)"]

# %%
y_test.head()
# Out:
# 36    32738.26290
# 37    36144.48122
# 38    37446.48609
# 39    32755.17682
# 40    38420.52289
# Name: per capita income (US$), dtype: float64

# %%
print('X_train: ', X_train.shape)
print("y_train: ", y_train.shape)
print("X_test: ", X_test.shape)
print('y_test: ',y_test.shape)
# Out:
# X_train:  (37, 1)
# y_train:  (37,)
# X_test:  (11, 1)
# y_test:  (11,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model  = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
slop = model.coef_

# %%
slop
# Out:
# array([616.93981285])

# %%
intercept = model.intercept_

# %%
intercept
# Out:
# -1212790.967852102

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([24790.29671772, 25407.23653057, 26024.17634341, 26641.11615626,
#        27258.05596911, 27874.99578195, 28491.9355948 , 29108.87540765,
#        29725.81522049, 30342.75503334, 30959.69484618])

# %%
model.score(X_train,y_train)
# Out:
# 0.9057186753165455

# %%
diffe = y_test-y_pred

# %%
diffe
# Out:
# 36     7947.966182
# 37    10737.244689
# 38    11422.309747
# 39     6114.060664
# 40    11162.466921
# 41    14459.715428
# 42    14173.320375
# 43    13567.592962
# 44    11314.078380
# 45     4832.433947
# 46     3269.498784
# Name: per capita income (US$), dtype: float64

# %%
plt.plot(X_train,y_train)
plt.plot(X_test,y_test)
plt.plot(X_test,y_pred)

# %%
X = df[["year"]]

# %%
y = df["per capita income (US$)"]

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
yy_pred = model.predict(X)

# %%
plt.plot(X,y)
plt.plot(X_test,y_test)
plt.plot(y,yy_pred)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
X_test.shape
# Out:
# (16, 1)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([22132.18455106, 31971.19876346, 21312.26670003, 35250.8701676 ,
#        19672.43099796, 29511.44521036,  9833.41678556, 15572.84174279,
#         3274.07397729, 20492.34884899,  6553.74538142,  2454.15612625,
#         4913.90967935, 32791.1166145 , 27051.69165726, 10653.33463659])

# %%
slop = model.coef_

# %%
intercept = model.intercept_

# %%
plt.plot(X_train,y_train)
plt.plot(X_test,y_test)

# %%
x = 2015
y = slop[0]*x+intercept
print(y)
# Out:
# 36890.70586966304

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([22132.18455106, 31971.19876346, 21312.26670003, 35250.8701676 ,
#        19672.43099796, 29511.44521036,  9833.41678556, 15572.84174279,
#         3274.07397729, 20492.34884899,  6553.74538142,  2454.15612625,
#         4913.90967935, 32791.1166145 , 27051.69165726, 10653.33463659])

# %%
plt.plot(X,y_test)
plt.plot(X_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 plt.plot(X,y_test)
#       2 plt.plot(X_test,y_pred)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
# ...
