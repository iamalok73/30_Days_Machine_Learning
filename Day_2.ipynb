# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("all libreries import successfully")
# Out:
# all libreries import successfully

# %%
df = pd.read_csv(r"C:\Users\Alok\Downloads\canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df[["year"]].head(5)
# Out:
#    year
# 0  1970
# 1  1971
# 2  1972
# 3  1973
# 4  1974

# %%
df[["per capita income (US$)"]].head(5)
# Out:
#    per capita income (US$)
# 0              3399.299037
# 1              3768.297935
# 2              4251.175484
# 3              4804.463248
# 4              5576.514583

# %%
plt.figure(figsize=(7,4))

plt.scatter(df[["year"]],df[["per capita income (US$)"]],color = "r")
# plt.xlabel(df[["year"]])
# plt.ylabel(df[["per capita income (US$)"]])
plt.title("Graph bt year and price")
# Out:
# Text(0.5, 1.0, 'Graph bt year and price')

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(df[['year']],df[["per capita income (US$)"]])
# Out:
# LinearRegression()

# %%
y_pred = model.predict(df[['year']])

# %%
model.score(df[["year"]],df[["per capita income (US$)"]])
# Out:
# 0.890916917957032

# %%
slop = model.coef_

# %%
intercept = model.intercept_

# %%
year = int(input("enter the year: "))
price = slop[0]*year+intercept
price
# Out:
# enter the year:  2013
# array([35489.43856786])

# %%
plt.figure(figsize=(7,4))

plt.scatter(df[["year"]],df[["per capita income (US$)"]],color = "r")
plt.scatter(df[['year']],y_pred)
plt.title("Graph bt year and price")
# Out:
# Text(0.5, 1.0, 'Graph bt year and price')

# %%
diffe = y_pred-df[["per capita income (US$)"]]
diffe.head()
# Out:
#    per capita income (US$)
# 0             -3533.858704
# 1             -3074.392526
# 2             -2728.805000
# 3             -2453.627689
# 4             -2397.213949

# %%
model.score(df[["year"]],y_pred)
# Out:
# 1.0
